# %%
from plankapy import Planka, PasswordAuth

# %%
planka_url = "http://localhost:4000"
admin_email = "admin@example.com"

# %%
admin_password = "admin123"

# %%
planka = Planka(planka_url, PasswordAuth(admin_email, admin_password))

# %%
planka.me
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 planka.me
#
# File ~/Development/CEO_Dashboard/ceo-backend/.venv/lib/python3.12/site-packages/plankapy/interfaces.py:323, in Planka.me(self)
#     317 """Current Logged in User
#     318
#     319 Returns:
#     320     Current user
#     321 """
#     322 route = self.routes.get_me()
# --> 323 return User(**route()['item']).bind(self.routes)
#
# TypeError: User_.__init__() got an unexpected keyword argument 'role'
